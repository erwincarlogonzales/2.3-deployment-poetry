# %% [markdown]
# ### **Load Data**

# %%
import pandas as pd

# Function to load data from csv file.
def load_data(df):
    return pd.read_csv(file_path)

file_path = '../data/flight_df.csv'

# Load the dataset
df = load_data(file_path)
df.head()
# Out:
#    Age  Class  Flight Distance  Inflight wifi service  \
# 0   26      3             2062                      2
# 1   52      3              680                      5
# 2   28      1              188                      3
# 3   54      3              453                      3
# 4   40      1              775                      4
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                  3                       3              3
# 1                                  5                       5              5
# 2                                  5                       3              4
# 3                                  5                       5              5
# 4                                  3                       3              3
#
#    Food and drink  Online boarding  Seat comfort  ...  Baggage handling  \
# 0               2                2             2  ...                 3
# ...

# %% [markdown]
# ### **EDA**

# %%
# Explore the dataset
def explore_data(df):
    num_rows = df.shape[0]
    num_features = df.shape[1]
    data_types = df.dtypes
    
    print(f'Number of rows: {num_rows}')
    print(f'\nNumber of features: {num_features}')
    print('\nData Types:')
    print(data_types)
    
explore_data(df)
# Out:
# Number of rows: 20000
#
# Number of features: 23
#
# Data Types:
# Age                                  int64
# Class                                int64
# Flight Distance                      int64
# Inflight wifi service                int64
# Departure/Arrival time convenient    int64
# Ease of Online booking               int64
# Gate location                        int64
# Food and drink                       int64
# Online boarding                      int64
# Seat comfort                         int64
# Inflight entertainment               int64
# On-board service                     int64
# Leg room service                     int64
# Baggage handling                     int64
# Checkin service                      int64
# Inflight service                     int64
# Cleanliness                          int64
# Departure Delay in Minutes           int64
# Arrival Delay in Minutes             int64
# Gender_Male                          int64
# ...

# %%
# EDA
def perform_eda(df):
    duplicates = df.duplicated().sum()
    missing_values = df.isna().sum()
    
    print(f'Number of duplicate rows: {duplicates}')
    print(f'\nNumber of missing values: {missing_values}')

perform_eda(df)
# Out:
# Number of duplicate rows: 0
#
# Number of missing values: Age                                  0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# Gender_Male                          0
# Loyal Customer                       0
# Business Travel                      0
# ...

# %%
# Summary Statistics
statistics = df.describe().T
print('Summary Statistics')
statistics
# Out:
# Summary Statistics
#                                      count        mean          std   min  \
# Age                                20000.0    39.47725    15.108901   7.0
# Class                              20000.0     2.02780     0.963054   1.0
# Flight Distance                    20000.0  1188.54800  1001.136957  31.0
# Inflight wifi service              20000.0     2.72795     1.326886   0.0
# Departure/Arrival time convenient  20000.0     3.05610     1.531134   0.0
# Ease of Online booking             20000.0     2.75110     1.396799   0.0
# Gate location                      20000.0     2.97135     1.279575   0.0
# Food and drink                     20000.0     3.20210     1.332383   0.0
# Online boarding                    20000.0     3.25530     1.348485   0.0
# Seat comfort                       20000.0     3.43910     1.323434   1.0
# Inflight entertainment             20000.0     3.34910     1.333348   0.0
# ...

# %%
# Check for anomalous values
def check_column_values(df):
    print('Check all columns for anomalous values \n')
    
    # Loop through all columns and return all unique values
    for column_name in df.columns:
        print(f'Unique values in: {column_name}')
        print(df[column_name].unique())
        print('\n')
        
check_column_values(df)
# Out:
# Check all columns for anomalous values
#
# Unique values in: Age
# [26 52 28 54 40 79 41 24 49 59 21 57 25 22 29 48  9 30 42 17 32 44 27 43
#  46 37 53 23 12 33 10  7 15 65 20 34 31 39 56  8 60 36 69 58 62 51 47 16
#  63 38 72 70 64 18 71 35 45 68 55 11 67 14 19 50 66 61 13 77 80 85 73 75
#  74 78 76]
#
#
# Unique values in: Class
# [3 1 2]
#
#
# Unique values in: Flight Distance
# [2062  680  188 ... 3504 2875 1515]
#
#
# Unique values in: Inflight wifi service
# [2 5 3 4 0 1]
#
#
# Unique values in: Departure/Arrival time convenient
# [3 5 1 4 0 2]
#
#
# Unique values in: Ease of Online booking
# [3 5 1 2 0 4]
#
#
# Unique values in: Gate location
# [3 5 4 1 2 0]
#
#
# Unique values in: Food and drink
# [2 3 4 5 1 0]
#
#
# Unique values in: Online boarding
# [2 4 3 0 5 1]
#
#
# Unique values in: Seat comfort
# [2 4 3 5 1]
#
#
# Unique values in: Inflight entertainment
# [2 4 3 5 1 0]
#
#
# Unique values in: On-board service
# [3 4 1 5 2 0]
#
#
# Unique values in: Leg room service
# ...

# %% [markdown]
# ### **Visualization**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Format figures in dark mode
plt.style.use('dark_background')

# Create correlation heatmap
def plot_correlation(df):
    fig, ax = plt.subplots(figsize=(15, 5))
    
    # Define mask for a upper triangle
    mask = np.triu(np.ones_like(df.corr(), dtype=bool))
    
    # Plot the heatmap
    sns.heatmap(
        df.corr().round(2),
        ax=ax,
        mask=mask,
        vmin=-1,
        vmax=1,
        annot=True,
        cmap='BrBG'
    )
    
    ax.set_title('Triangle Correlation Heatmap')
    plt.show()
    
plot_correlation(df)

# %%
# Ranked correlation heatmap
def ranked_heatmap(df, target_column):
    plt.figure(figsize=(4, 8))
    
    # Plot the heatmap
    heatmap = sns.heatmap(
        df.corr()[[target_column]].sort_values(by=target_column, ascending=False),
        vmin=-1,
        vmax=1,
        annot=True,
        cmap='BrBG'
    )
    
    heatmap.set_title(f'Features Correlating with {target_column}')
    plt.show()

ranked_heatmap(df, target_column='satisfied')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create histogram and boxplot
def visualize_data(df, column_name):
    fig, axes = plt.subplots(
        figsize=(10, 6),
        nrows=2,
        sharex=False
    )
    sns.set_style('dark')
    
    # Histogram
    sns.histplot(
        df[column_name],
        ax=axes[0],
        bins='auto',
        kde=True
    )
    axes[0].tick_params(axis='x', rotation=45)
    
    # Barplot
    sns.boxplot(
        data=df,
        x=column_name,
        ax=axes[1]
    )
    plt.tight_layout()
    plt.show()

visualize_data(df, column_name='Flight Distance')

# %%
df.columns
# Out:
# Index(['Age', 'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'Gender_Male', 'Loyal Customer', 'Business Travel', 'satisfied'],
#       dtype='object')
